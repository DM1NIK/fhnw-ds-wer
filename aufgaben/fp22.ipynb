# %%
import math
from scipy import stats
import util

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# (a)

# %%
stats.binom.pmf(2,5,0.8)
# Out:
# 0.0512

# %% [markdown]
# (b)

# %%
0.8 * 6 * 5
# Out:
# 24.000000000000004

# %% [markdown]
# (c)

# %%
stats.binom.pmf(4, 6, 0.73728) + stats.binom.pmf(5, 6, 0.73728) + stats.binom.pmf(6, 6, 0.73728)
# OR
1 - stats.binom.cdf(3, 6, 0.73728)
# Out:
# 0.8099428436505376

# %% [markdown]
# (d)

# %%
sum = 0
for i in range(1,6):
    sum += stats.binom.pmf(i, 5, 0.8)**6

sum
# Out:
# 0.0060341115129170925

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (a)

# %%
p_behandlung = 0.02
n_ksb = 400000

stats.binom.cdf(7800, n_ksb, p_behandlung)
# Out:
# 0.011892688154907509

# %% [markdown]
# (b)

# %%
1 - stats.binom.cdf(8100 - 1, n_ksb, p_behandlung)
# 8100 - 1 da mindestens
# Out:
# 0.1306612003804165

# %% [markdown]
# (c)

# %%
e = n_ksb * p_behandlung
s = math.sqrt(e*(1-p_behandlung))

stats.binom.cdf(e + s, n_ksb, p_behandlung) - stats.binom.cdf(e - s, n_ksb, p_behandlung)
# Out:
# 0.682452547107721

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = 1600
u0 = 800
u = 840
s = 400

# %% [markdown]
# (a): t-test fuer den Mittelwert
#
# (b):
# einseitige Fragestellung
# - HA: u > u0
# - H0: u <= u0
#
# (c)

# %%
t, c, p = util.calculate_t_test(n, u, u0, s, 1 -.99, side='right')
t
# Out:
# H0: rejected
# 4.0

# %% [markdown]
# (d)

# %%
print(c, u + c * s)
# Out:
# 2.3286822417397337 1771.4728966958935

# %% [markdown]
# (e) H0 muss verworfen werden. Damit kamm man Sagen, dass sich die Sparleistung erhoeht hat (a = .01).

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# a
u = 1000
s = 150

stats.norm.cdf(900, loc=u, scale=s)
# Out:
# 0.2524925375469229

# %%
# b
stats.norm.rvs()
# Out:
# -0.8893319172307446
