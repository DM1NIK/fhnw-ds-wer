# %%
import math
import random

import numpy as np
from scipy import stats
import sympy as sym
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = [6, 8, 3, 10, 1, 12, 3, 12, 7, 5, 10, 9, 6, 6, 11, 7, 6, 10, 9, 7]

plt.hist(data)
plt.title("Achieved points in a test")
plt.xlabel("Points")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data_s = "182.0 176.0 191.0 173.5 183.0 178.0 179.0 174.0 184.5 174.0 180.5 174.5 178.5 169.0 178.5 168.5 179.0 177.0 172.5 171.0 176.5 167.0 175.0 175.0"
data = [float(x) for x in data_s.split()]

class_width = 2
bins = math.ceil((max(data) - min(data)) / class_width) + 1

plt.hist(data, bins=bins)
# Out:
# (array([2., 1., 2., 3., 4., 3., 4., 1., 2., 1., 0., 0., 1.]),
#  array([167.        , 168.84615385, 170.69230769, 172.53846154,
#         174.38461538, 176.23076923, 178.07692308, 179.92307692,
#         181.76923077, 183.61538462, 185.46153846, 187.30769231,
#         189.15384615, 191.        ]),
#  <BarContainer object of 13 artists>)

# %%
class_width = 4
bins = math.ceil((max(data) - min(data)) / class_width) + 1
plt.hist(data, bins=bins)
# Out:
# (array([3., 3., 8., 6., 2., 1., 1.]),
#  array([167.        , 170.42857143, 173.85714286, 177.28571429,
#         180.71428571, 184.14285714, 187.57142857, 191.        ]),
#  <BarContainer object of 7 artists>)
